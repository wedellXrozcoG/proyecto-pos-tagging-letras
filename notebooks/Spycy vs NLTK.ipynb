# %%
import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))
from src.visualization.comparison_plots import POSVisualizer
import pandas as pd
corpus_spacy = POSVisualizer('../data/processed/spotify_clean02.csv')
# Out:
# Cargando modelo de Spacy...
# ✓ Modelo de Spacy cargado correctamente
#
# ...
# ¡Listo para comenzar con el POS Tagging!
# ...

# %%
visualizer = POSVisualizer("../data/results/comparisons.csv")
visualizer.comparar_distribucion()
visualizer.mostrar_metricas()
# Out:
# MÉTRICAS COMPARATIVAS
# ...
# Total tokens NLTK:  1,640
# Total tokens Spacy: 1,640
#
# Tipos únicos NLTK:  30
# Tipos únicos Spacy: 15

# %% [markdown]
# ## Rendimiento Spacy

# %%
corpus_spacy.multiples_spacyF2_time("text")
# Out:
# Procesando: 100%|██████████| 10000/10000 [11:58<00:00, 13.92it/s]
# ¡Proceso finalizado!
# --- MÉTRICAS DE RENDIMIENTO ---
# Tiempo total: 11 min 58.28 seg
# Velocidad: 13.92 canciones/seg
# Latencia: 71.83 ms por canción
