# %%
import pandas as pd

# %%
import sys
import os

# Pon la ruta exacta de la carpeta donde ESTÁ el archivo .py
ruta = r"D:\proyecto-pos-tagging-letras\src\data"

if ruta not in sys.path:
    sys.path.append(ruta)

# Intentar importar
from preprocessorEDA import preprocesador
print("✅ Importado correctamente")
# Out:
# ✅ Importado correctamente

# %%
spotify_clean = pd.read_csv('../data/processed/spotify_clean02.csv', sep=';', na_values=[''], quotechar='"')
spotify_clean
# Out:
#                                                     text  emotion  \
# 0      I always evaded the truth Continued to lose a ...    anger
# 1      Roddy’s daddy Denny saved every penny To buy a...      joy
# 2      Yeah, gang Ain't gon' lie, we in this bitch de...     fear
# 3      I’m gone for that yay yay Shawty ass like yay ...    anger
# 4      One bright day thing will be better again to m...      joy
# ...                                                  ...      ...
# 99995  Let's go! The fuck it is, nigga H.I.T.Z. Commi...    anger
# 99996  Yeah yeah, oh yeah Yeah yeah, oh yeah Yeah yea...  sadness
# 99997  I'm gonna stand up straight, hold back my shou...      joy
# 99998  Nacho Picasso, Seattle's own step child With m...    anger
# 99999  This is a song called "Stone" Well, the night ...      joy
#
#        Release Date    Genre Explicit  Popularity
# 0              2017  hip hop      Yes          24
# 1              2013  hip hop       No          41
# 2              2021  hip hop      Yes          53
# 3              2013  hip hop       No           9
# 4              2015  hip hop       No          28
# ...             ...      ...      ...         ...
# 99995          2008  hip hop      Yes           1
# 99996          2016  hip hop       No          23
# 99997          2018  hip hop       No          22
# 99998          2024  hip hop      Yes           7
# 99999          2021  hip hop       No          38
#
# [100000 rows x 6 columns]

# %%
procesar = preprocesador(spotify_clean)

# %%
procesar.mostrar_head()
# Out:
#                                                 text emotion  Release Date  \
# 0  I always evaded the truth Continued to lose a ...   anger          2017
# 1  Roddy’s daddy Denny saved every penny To buy a...     joy          2013
# 2  Yeah, gang Ain't gon' lie, we in this bitch de...    fear          2021
# 3  I’m gone for that yay yay Shawty ass like yay ...   anger          2013
# 4  One bright day thing will be better again to m...     joy          2015
#
#      Genre Explicit  Popularity
# 0  hip hop      Yes          24
# 1  hip hop       No          41
# 2  hip hop      Yes          53
# 3  hip hop       No           9
# 4  hip hop       No          28

# %%
procesar.mostrar_info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   text          99998 non-null   str
#  1   emotion       100000 non-null  str
#  2   Release Date  100000 non-null  int64
#  3   Genre         100000 non-null  str
#  4   Explicit      100000 non-null  str
#  5   Popularity    100000 non-null  int64
# dtypes: int64(2), str(4)
# memory usage: 4.6 MB

# %%
procesar.mostrar_dimensiones()
# Out:
# (100000, 6)

# %%
procesar.mostrar_valores_nulos()
# Out:
# text            2
# emotion         0
# Release Date    0
# Genre           0
# Explicit        0
# Popularity      0
# dtype: int64

# %%
procesar.resum_transpose()
# Out:
#                  count        mean        std     min     25%     50%     75%  \
# Release Date  100000.0  2015.72977   6.928065  1990.0  2013.0  2018.0  2020.0
# Popularity    100000.0    30.56669  18.000967     0.0    18.0    28.0    42.0
#
#                  max
# Release Date  2024.0
# Popularity      95.0

# %%
procesar.ch_bool("Explicit")
# Out:
#                                                     text  emotion  \
# 0      I always evaded the truth Continued to lose a ...    anger
# 1      Roddy’s daddy Denny saved every penny To buy a...      joy
# 2      Yeah, gang Ain't gon' lie, we in this bitch de...     fear
# 3      I’m gone for that yay yay Shawty ass like yay ...    anger
# 4      One bright day thing will be better again to m...      joy
# ...                                                  ...      ...
# 99995  Let's go! The fuck it is, nigga H.I.T.Z. Commi...    anger
# 99996  Yeah yeah, oh yeah Yeah yeah, oh yeah Yeah yea...  sadness
# 99997  I'm gonna stand up straight, hold back my shou...      joy
# 99998  Nacho Picasso, Seattle's own step child With m...    anger
# 99999  This is a song called "Stone" Well, the night ...      joy
#
#        Release Date    Genre Explicit  Popularity
# 0              2017  hip hop        1          24
# 1              2013  hip hop        0          41
# 2              2021  hip hop        1          53
# 3              2013  hip hop        0           9
# 4              2015  hip hop        0          28
# ...             ...      ...      ...         ...
# 99995          2008  hip hop        1           1
# 99996          2016  hip hop        0          23
# 99997          2018  hip hop        0          22
# 99998          2024  hip hop        1           7
# 99999          2021  hip hop        0          38
#
# [100000 rows x 6 columns]

# %%
procesar.grafico_barras("Explicit","Distribución de canciones:")

# %%
procesar.grafico_pie("emotion","Distribución de canciones")
