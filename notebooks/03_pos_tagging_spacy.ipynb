# %%
import pandas as pd
import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))

from src.pos_tagging.spacy_tagger import pos_spacy

print("✅ Funciona")
# Out:
# Cargando modelo de Spacy...
# ✓ Modelo de Spacy cargado correctamente
#
# ============================================================
# ¡Listo para comenzar con el POS Tagging!
# ============================================================
# ✅ Funciona

# %%
spotify_clean02 = pd.read_csv('../data/processed/spotify_clean02.csv', sep=';', na_values=[''], quotechar='"')
spotify_clean02
# Out:
#                                                    text  emotion  \
# 0     I always evaded the truth Continued to lose a ...    anger
# 1     Roddy s daddy Denny saved every penny To buy a...      joy
# 2     Yeah gang Ain't gon' lie we in this bitch deep...     fear
# 3     I m gone for that yay yay Shawty ass like yay ...    anger
# 4     One bright day thing will be better again to m...      joy
# ...                                                 ...      ...
# 9995  Never really felt bad about it As we drank dee...  sadness
# 9996  I have traveled many moonless nights Cold and ...     fear
# 9997  Ooh tell me what I could do This ain't what it...      joy
# 9998  Today I heard our favorite song on the radio I...  sadness
# 9999  I said you wanna be startin' somethin' You got...  sadness
#
#       Release Date    Genre Explicit  Popularity
# 0             2017  hip hop      Yes          24
# 1             2013  hip hop       No          41
# 2             2021  hip hop      Yes          53
# 3             2013  hip hop       No           9
# 4             2015  hip hop       No          28
# ...            ...      ...      ...         ...
# 9995          2013      pop       No          71
# 9996          1992      pop       No          32
# 9997          2018      pop      Yes          43
# 9998          2012      pop       No          34
# 9999          2012      pop       No          28
#
# [10000 rows x 6 columns]

# %%
corpus_spacy = pos_spacy(spotify_clean02)

# %%
corpus_spacy.unica_spacy("text")
# Out:
# ORACIÓN ORIGINAL:
# "Look up from the screen My god Ran away Don t run away We ran away Don t we run away One I can t become One to one I can t be one One Wake up from a nap Be glad Ran away Don t run away We ran away Don t we run away One I can t become One to one I can't be one One to one One to one One to one One to one"
#
# POS TAGGING CON SPACY(Una sola canción):
# Token              POS    Fine POS  Lemma
# --------------------------------------------------
# Look             VERB    VB        look
# up               ADP     RP        up
# from             ADP     IN        from
# the              DET     DT        the
# screen           NOUN    NN        screen
# My               PRON    PRP$      my
# god              NOUN    NN        god
# Ran              VERB    VBD       run
# away             ADV     RB        away
# Don              PROPN   NNP       Don
# t                NOUN    NN        t
# run              VERB    VBD       run
# away             ADV     RB        away
# We               PRON    PRP       we
# ran              VERB    VBD       run
# away             ADV     RB        away
# Don              PROPN   NNP       Don
# t                NOUN    NN        t
# we               PRON    PRP       we
# run              VERB    VBP       run
# away             ADV     RB        away
# One              NUM     CD        one
# I                PRON    PRP       I
# can              AUX     MD        can
# t                VERB    VB        t
# become           VERB    VB        become
# One              NUM     CD        one
# to               ADP     IN        to
# one              NUM     CD        one
# I                PRON    PRP       I
# can              AUX     MD        can
# t                VERB    VB        t
# be               AUX     VB        be
# one              NUM     CD        one
# One              NUM     CD        one
# Wake             VERB    VB        wake
# up               ADP     RP        up
# from             ADP     IN        from
# a                DET     DT        a
# nap              NOUN    NN        nap
# Be               AUX     VB        be
# glad             ADJ     JJ        glad
# Ran              PROPN   NNP       Ran
# away             ADV     RB        away
# Don              PROPN   NNP       Don
# t                NOUN    NN        t
# run              VERB    VBD       run
# away             ADV     RB        away
# We               PRON    PRP       we
# ran              VERB    VBD       run
# away             ADV     RB        away
# Don              PROPN   NNP       Don
# t                NOUN    NN        t
# we               PRON    PRP       we
# run              VERB    VBP       run
# away             ADV     RB        away
# One              NUM     CD        one
# I                PRON    PRP       I
# can              AUX     MD        can
# t                VERB    VB        t
# become           VERB    VB        become
# One              NUM     CD        one
# to               ADP     IN        to
# one              NUM     CD        one
# I                PRON    PRP       I
# ca               AUX     MD        can
# n't              PART    RB        not
# be               AUX     VB        be
# one              NUM     CD        one
# One              NUM     CD        one
# to               ADP     IN        to
# one              NUM     CD        one
# One              NUM     CD        one
# to               ADP     IN        to
# one              NUM     CD        one
# One              NUM     CD        one
# to               ADP     IN        to
# one              NUM     CD        one
# One              NUM     CD        one
# to               ADP     IN        to
# one              NUM     CD        one

# %%
resultado_spacy = corpus_spacy.pipeline_completo("text")
# Out:
# 100%|██████████| 10000/10000 [10:12<00:00, 16.34it/s]

# %%
resultado_spacy
# Out:
#          cancion_id   token    pos  tag  is_stopword  entity   lower   lemma  \
# 0                 1       I   PRON  PRP         True               i       I
# 1                 1  always    ADV   RB         True          always  always
# 2                 1  evaded   VERB  VBD        False          evaded   evade
# 3                 1     the    DET   DT         True             the     the
# 4                 1   truth   NOUN   NN        False           truth   truth
# ...             ...     ...    ...  ...          ...     ...     ...     ...
# 3492482       10000      se  PROPN  NNP        False  PERSON      se      se
# 3492483       10000      ma  PROPN  NNP        False  PERSON      ma      ma
# 3492484       10000      ma  PROPN  NNP        False  PERSON      ma      ma
# 3492485       10000     coo  PROPN  NNP        False  PERSON     coo     coo
# 3492486       10000      sa  PROPN  NNP        False  PERSON      sa      sa
#
#               dep
# 0           nsubj
# 1          advmod
# 2            ROOT
# 3             det
# 4            dobj
# ...           ...
# 3492482  compound
# 3492483  compound
# 3492484  compound
# 3492485  compound
# 3492486      ROOT
#
# [3492487 rows x 9 columns]

# %%
resultado_spacy.to_csv(r"D:\proyecto-pos-tagging-letras\data\processed\pipeline_spacy.csv", index=False)
