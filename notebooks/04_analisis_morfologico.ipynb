# %%
import sys
import os

# Pon la ruta exacta de la carpeta donde ESTÁ el archivo .py
ruta = r"D:\proyecto-pos-tagging-letras\src\visualization"

if ruta not in sys.path:
    sys.path.append(ruta)

# Intentar importar
from pos_plots import graficos
print("✅ Importado correctamente")
# Out:
# Cargando modelo de Spacy...
# ✓ Modelo de Spacy cargado correctamente
#
# ============================================================
# ¡Listo para comenzar con el POS Tagging!
# ============================================================
# ✅ Importado correctamente

# %% [markdown]
# ## ¿Existe alguna diferencia de contenido entre una canción explicita o no en el hip hop?

# %%
import pandas as pd
spotify_clean02 = pd.read_csv('../data/processed/spotify_clean02.csv', sep=';', na_values=[''], quotechar='"')
spotify_clean02
# Out:
#                                                    text  emotion  \
# 0     I always evaded the truth Continued to lose a ...    anger
# 1     Roddy s daddy Denny saved every penny To buy a...      joy
# 2     Yeah gang Ain't gon' lie we in this bitch deep...     fear
# 3     I m gone for that yay yay Shawty ass like yay ...    anger
# 4     One bright day thing will be better again to m...      joy
# ...                                                 ...      ...
# 9995  Your blade will go too deep if you keep trying...      joy
# 9996  Ayy ayy Ayy got the trap jumpin' Ooh ayy yeah ...  sadness
# 9997  You show me the light And even if I don't know...      joy
# 9998  Someone said there was a time when it costed a...    anger
# 9999  Golden eyes watching our every move Losing tim...      joy
#
#       Release Date    Genre Explicit  Popularity
# 0             2017  hip hop      Yes          24
# 1             2013  hip hop       No          41
# 2             2021  hip hop      Yes          53
# 3             2013  hip hop       No           9
# 4             2015  hip hop       No          28
# ...            ...      ...      ...         ...
# 9995          2017  hip hop       No          42
# 9996          2018  hip hop      Yes          11
# 9997          2016  hip hop       No          17
# 9998          2019  hip hop      Yes          19
# 9999          2017  hip hop       No          39
#
# [10000 rows x 6 columns]

# %%
corpus = graficos(spotify_clean02)

# %%
corpus.mostrar_head()
# Out:
#                                                 text emotion  Release Date  \
# 0  I always evaded the truth Continued to lose a ...   anger          2017
# 1  Roddy s daddy Denny saved every penny To buy a...     joy          2013
# 2  Yeah gang Ain't gon' lie we in this bitch deep...    fear          2021
# 3  I m gone for that yay yay Shawty ass like yay ...   anger          2013
# 4  One bright day thing will be better again to m...     joy          2015
#
#      Genre Explicit  Popularity
# 0  hip hop      Yes          24
# 1  hip hop       No          41
# 2  hip hop      Yes          53
# 3  hip hop       No           9
# 4  hip hop       No          28

# %%
corpus.ch_bool("Explicit")
# Out:
#                                                    text  emotion  \
# 0     I always evaded the truth Continued to lose a ...    anger
# 1     Roddy s daddy Denny saved every penny To buy a...      joy
# 2     Yeah gang Ain't gon' lie we in this bitch deep...     fear
# 3     I m gone for that yay yay Shawty ass like yay ...    anger
# 4     One bright day thing will be better again to m...      joy
# ...                                                 ...      ...
# 9995  Your blade will go too deep if you keep trying...      joy
# 9996  Ayy ayy Ayy got the trap jumpin' Ooh ayy yeah ...  sadness
# 9997  You show me the light And even if I don't know...      joy
# 9998  Someone said there was a time when it costed a...    anger
# 9999  Golden eyes watching our every move Losing tim...      joy
#
#       Release Date    Genre Explicit  Popularity
# 0             2017  hip hop        1          24
# 1             2013  hip hop        0          41
# 2             2021  hip hop        1          53
# 3             2013  hip hop        0           9
# 4             2015  hip hop        0          28
# ...            ...      ...      ...         ...
# 9995          2017  hip hop        0          42
# 9996          2018  hip hop        1          11
# 9997          2016  hip hop        0          17
# 9998          2019  hip hop        1          19
# 9999          2017  hip hop        0          39
#
# [10000 rows x 6 columns]

# %%
corpus.auto_grafico_pos_total("text","Explicit")
# Out:
# 🚀 Iniciando procesamiento de 10000 canciones...
# Analizando: 100%|██████████| 10000/10000 [01:57<00:00, 85.01it/s]
# 📊 Generando gráfico final...
