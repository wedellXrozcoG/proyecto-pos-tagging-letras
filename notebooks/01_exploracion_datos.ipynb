# %%
import pandas as pd
import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))

from src.data.preprocessorEDA import preprocesador
print("✅ Funciona")
# Out:
# ✅ Funciona

# %%
spotify_clean = pd.read_csv('../data/processed/spotify_clean02.csv', sep=';', na_values=[''], quotechar='"')
spotify_clean
# Out:
#                                                    text  emotion  \
# 0     I always evaded the truth Continued to lose a ...    anger
# 1     Roddy s daddy Denny saved every penny To buy a...      joy
# 2     Yeah gang Ain't gon' lie we in this bitch deep...     fear
# 3     I m gone for that yay yay Shawty ass like yay ...    anger
# 4     One bright day thing will be better again to m...      joy
# ...                                                 ...      ...
# 9995  Never really felt bad about it As we drank dee...  sadness
# 9996  I have traveled many moonless nights Cold and ...     fear
# 9997  Ooh tell me what I could do This ain't what it...      joy
# 9998  Today I heard our favorite song on the radio I...  sadness
# 9999  I said you wanna be startin' somethin' You got...  sadness
#
#       Release Date    Genre Explicit  Popularity
# 0             2017  hip hop      Yes          24
# 1             2013  hip hop       No          41
# ...

# %%
procesar = preprocesador(spotify_clean)

# %%
procesar.mostrar_head()
# Out:
#                                                 text emotion  Release Date  \
# 0  I always evaded the truth Continued to lose a ...   anger          2017
# 1  Roddy s daddy Denny saved every penny To buy a...     joy          2013
# 2  Yeah gang Ain't gon' lie we in this bitch deep...    fear          2021
# 3  I m gone for that yay yay Shawty ass like yay ...   anger          2013
# 4  One bright day thing will be better again to m...     joy          2015
#
#      Genre Explicit  Popularity
# 0  hip hop      Yes          24
# 1  hip hop       No          41
# 2  hip hop      Yes          53
# 3  hip hop       No           9
# 4  hip hop       No          28

# %%
procesar.mostrar_info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   text          10000 non-null  str
#  1   emotion       10000 non-null  str
#  2   Release Date  10000 non-null  int64
#  3   Genre         10000 non-null  str
#  4   Explicit      10000 non-null  str
#  5   Popularity    10000 non-null  int64
# dtypes: int64(2), str(4)
# memory usage: 468.9 KB

# %%
procesar.mostrar_dimensiones()
# Out:
# (10000, 6)

# %%
procesar.mostrar_valores_nulos()
# Out:
# text            0
# emotion         0
# Release Date    0
# Genre           0
# Explicit        0
# Popularity      0
# dtype: int64

# %%
procesar.resum_transpose()
# Out:
#                 count       mean        std     min     25%     50%     75%  \
# Release Date  10000.0  2015.0582   7.637594  1990.0  2012.0  2017.0  2020.0
# Popularity    10000.0    34.0379  18.792274     0.0    20.0    32.0    46.0
#
#                  max
# Release Date  2024.0
# Popularity      94.0

# %%
procesar.ch_bool("Explicit")
# Out:
#                                                    text  emotion  \
# 0     I always evaded the truth Continued to lose a ...    anger
# 1     Roddy s daddy Denny saved every penny To buy a...      joy
# 2     Yeah gang Ain't gon' lie we in this bitch deep...     fear
# 3     I m gone for that yay yay Shawty ass like yay ...    anger
# 4     One bright day thing will be better again to m...      joy
# ...                                                 ...      ...
# 9995  Never really felt bad about it As we drank dee...  sadness
# 9996  I have traveled many moonless nights Cold and ...     fear
# 9997  Ooh tell me what I could do This ain't what it...      joy
# 9998  Today I heard our favorite song on the radio I...  sadness
# 9999  I said you wanna be startin' somethin' You got...  sadness
#
#       Release Date    Genre Explicit  Popularity
# 0             2017  hip hop        1          24
# 1             2013  hip hop        0          41
# ...

# %%
procesar.grafico_barras("Explicit","Distribución de canciones:")

# %%
procesar.grafico_pie("emotion","Distribución de canciones")

# %%
import sys
import os

# Pon la ruta exacta de la carpeta donde ESTÁ el archivo .py
#ruta = r"D:\proyecto-pos-tagging-letras\src\data"

#if ruta not in sys.path:
 #   sys.path.append(ruta)

# Intentar importar
from src.data.preprocessorEDA import preprocesador
print("✅ Importado correctamente")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 11
#       2 import os
#       4 # Pon la ruta exacta de la carpeta donde ESTÁ el archivo .py
#       5 #ruta = r"D:\proyecto-pos-tagging-letras\src\data"
#       6
#    (...)      9
#      10 # Intentar importar
# ---> 11 from src.data.preprocessorEDA import preprocesador
#      12 print("✅ Importado correctamente")
#
# ModuleNotFoundError: No module named 'src'

# %%
spotify_clean = pd.read_csv('../data/processed/spotify_clean02.csv', sep=';', na_values=[''], quotechar='"')
spotify_clean
# Out:
#                                                     text  emotion  \
# 0      I always evaded the truth Continued to lose a ...    anger
# 1      Roddy s daddy Denny saved every penny To buy a...      joy
# 2      Yeah gang Ain't gon' lie we in this bitch deep...     fear
# 3      I m gone for that yay yay Shawty ass like yay ...    anger
# 4      One bright day thing will be better again to m...      joy
# ...                                                  ...      ...
# 49993  Perfect Yeah Running back it's time running ba...      joy
# 49994  Hmmmm You touch my tralala Hmmm my ding ding d...     love
# 49995  Yeah yeah yeah Hungry Nigga I heard you were h...    anger
# 49996  Now for so long you made me sweat After all th...  sadness
# 49997  We follow down The road And we follow down The...    anger
#
#        Release Date    Genre Explicit  Popularity
# 0              2017  hip hop      Yes          24
# 1              2013  hip hop       No          41
# ...

# %%
procesar = preprocesador(spotify_clean)

# %%
procesar.mostrar_head()
# Out:
#                                                 text emotion  Release Date  \
# 0  I always evaded the truth Continued to lose a ...   anger          2017
# 1  Roddy s daddy Denny saved every penny To buy a...     joy          2013
# 2  Yeah gang Ain't gon' lie we in this bitch deep...    fear          2021
# 3  I m gone for that yay yay Shawty ass like yay ...   anger          2013
# 4  One bright day thing will be better again to m...     joy          2015
#
#      Genre Explicit  Popularity
# 0  hip hop      Yes          24
# 1  hip hop       No          41
# 2  hip hop      Yes          53
# 3  hip hop       No           9
# 4  hip hop       No          28

# %%
procesar.mostrar_info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 49998 entries, 0 to 49997
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   text          49998 non-null  str
#  1   emotion       49998 non-null  str
#  2   Release Date  49998 non-null  int64
#  3   Genre         49998 non-null  str
#  4   Explicit      49998 non-null  str
#  5   Popularity    49998 non-null  int64
# dtypes: int64(2), str(4)
# memory usage: 2.3 MB

# %%
procesar.mostrar_dimensiones()
# Out:
# (49998, 6)

# %%
procesar.mostrar_valores_nulos()
# Out:
# text            0
# emotion         0
# Release Date    0
# Genre           0
# Explicit        0
# Popularity      0
# dtype: int64

# %%
procesar.resum_transpose()
# Out:
#                 count         mean        std     min     25%     50%     75%  \
# Release Date  49998.0  2015.742210   6.923658  1990.0  2013.0  2018.0  2020.0
# Popularity    49998.0    30.583723  18.005957     0.0    18.0    28.0    42.0
#
#                  max
# Release Date  2024.0
# Popularity      93.0

# %%
procesar.ch_bool("Explicit")
# Out:
#                                                     text  emotion  \
# 0      I always evaded the truth Continued to lose a ...    anger
# 1      Roddy s daddy Denny saved every penny To buy a...      joy
# 2      Yeah gang Ain't gon' lie we in this bitch deep...     fear
# 3      I m gone for that yay yay Shawty ass like yay ...    anger
# 4      One bright day thing will be better again to m...      joy
# ...                                                  ...      ...
# 49993  Perfect Yeah Running back it's time running ba...      joy
# 49994  Hmmmm You touch my tralala Hmmm my ding ding d...     love
# 49995  Yeah yeah yeah Hungry Nigga I heard you were h...    anger
# 49996  Now for so long you made me sweat After all th...  sadness
# 49997  We follow down The road And we follow down The...    anger
#
#        Release Date    Genre Explicit  Popularity
# 0              2017  hip hop        1          24
# 1              2013  hip hop        0          41
# ...

# %%
procesar.grafico_barras("Explicit","Distribución de canciones:")

# %%
procesar.grafico_pie("emotion","Distribución de canciones")
