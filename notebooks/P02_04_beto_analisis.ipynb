# %% [markdown]
# # ANÁLISIS POLISÉMICO CONTEXTUAL Y MLM BERT

# %%
from src.db_manager import get_collection
from src.analisis_nlp.Bert.embeddings_bert import Bert

# %% [markdown]
# # Llamado y ejecución del MongoDB

# %%
col = get_collection()

# %%
#ESTO SOLO SE CORRE UNA VEZ (a no ser que se reinicie kernel)
bert = Bert(col)
# Out:
# 🤖 Cargando BERT y preparando entorno...
# ...
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 390.73it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ...

# %% [markdown]
# # Polisemia Contextual

# %%
bert.ejecutar_polisemia()
# Out:
# --------------------------------------------------
# ANALIZANDO: DIE
#
#   Canción 1: [POP] Butterflies - Fiji Blue
#   Contexto : "...You really make me wanna fly Cross my heart and hope to die Lonely you're the reason why I can feel those butterflies When I..."
#   Tokens   : ['[CLS]', 'you', 'really', 'make', 'me', 'wanna', 'fly', 'cross', 'my', 'heart', 'and', 'hope', 'to', 'die', 'lonely']...
#
#   Canción 2: [POP] Getting Married Today - Glee Cast
#   Contexto : "...go Look you know I adore you all But why Watch me die Like Eliza on the ice Look perhaps I'll collapse In the apse..."
#   Tokens   : ['[CLS]', 'go', 'look', 'you', 'know', 'i', 'ad', '##ore', 'you', 'all', 'but', 'why', 'watch', 'me', 'die']...
#
#   Similitud coseno (BERT): 0.6679
# 💚 Resultado: Uso Semejante
#
# --------------------------------------------------
# ANALIZANDO: BEAT
#
#   Canción 1: [POP] So Mi Like It Remix - Spice
# ...

# %% [markdown]
# # Masked Language Model MLM

# %%
bert.ejecutar_mlm()
# Out:
# GÉNERO: ROCK
# bad idea right? - Olivia Rodrigo
# Frase corta: "Hey Haven't heard from you [MASK] a couple of months But I'm out right now and I'm all fucked up And you're callin' my phone you're all alone And I'm"
# ¿Qué palabra falta? (Original: 'in')
#    1. in (0.890) 💚
#    2. for (0.108)
#    3. since (0.001)
# ----------------------------------------
#
# GÉNERO: POP
# I'll Be There - Aiza Seguerra
# Frase corta: "When you wake up each morning And you feel like calling I'll be there for you When the road seems uncertain And you [MASK] stop the hurtin' I'll be there"
# ¿Qué palabra falta? (Original: 'can't')
#    1. can (0.572)
#    2. never (0.210)
#    3. gotta (0.073)
# ----------------------------------------
#
# GÉNERO: HIP HOP
# Naked Girl - The Velvet Teen
# Frase corta: "Smile You [MASK] be my shield You'll be the only thing Anyone ever sees Kill Crush me break my will Cease the endless rats inside the walls That squeak and"
# ¿Qué palabra falta? (Original: 'will')
# ...
