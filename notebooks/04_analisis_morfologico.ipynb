# %%
import pandas as pd
import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))

from src.analysis.Analisismorfologico import AnalisisMorfologico
print("✅ Funciona")
# Out:
# ✅ Funciona

# %%
spotify_clean02 = pd.read_csv('../data/processed/spotify_clean02.csv', sep=';', na_values=[''], quotechar='"')
spotify_clean02
# Out:
#                                                    text  emotion  \
# 0     I always evaded the truth Continued to lose a ...    anger
# 1     Roddy s daddy Denny saved every penny To buy a...      joy
# 2     Yeah gang Ain't gon' lie we in this bitch deep...     fear
# 3     I m gone for that yay yay Shawty ass like yay ...    anger
# 4     One bright day thing will be better again to m...      joy
# ...                                                 ...      ...
# 9995  Never really felt bad about it As we drank dee...  sadness
# 9996  I have traveled many moonless nights Cold and ...     fear
# 9997  Ooh tell me what I could do This ain't what it...      joy
# 9998  Today I heard our favorite song on the radio I...  sadness
# 9999  I said you wanna be startin' somethin' You got...  sadness
#
#       Release Date    Genre Explicit  Popularity
# 0             2017  hip hop      Yes          24
# 1             2013  hip hop       No          41
# 2             2021  hip hop      Yes          53
# 3             2013  hip hop       No           9
# 4             2015  hip hop       No          28
# ...            ...      ...      ...         ...
# 9995          2013      pop       No          71
# 9996          1992      pop       No          32
# 9997          2018      pop      Yes          43
# 9998          2012      pop       No          34
# 9999          2012      pop       No          28
#
# [10000 rows x 6 columns]

# %% [markdown]
# ## Distribución POS completa

# %%
# Leer el archivo
df = pd.read_pickle(r"..\data\processed\lyrics_pos_tagged.pkl")

# %%
corpus = AnalisisMorfologico(spotify_clean02)

# %%
corpus.procesar_corpus()
# Out:
# Procesando corpus...
#   ✓ 500/10000 procesadas
#   ✓ 1000/10000 procesadas
#   ✓ 1500/10000 procesadas
#   ✓ 2000/10000 procesadas
#   ✓ 2500/10000 procesadas
#   ✓ 3000/10000 procesadas
#   ✓ 3500/10000 procesadas
#   ✓ 4000/10000 procesadas
#   ✓ 4500/10000 procesadas
#   ✓ 5000/10000 procesadas
#   ✓ 5500/10000 procesadas
#   ✓ 6000/10000 procesadas
#   ✓ 6500/10000 procesadas
#   ✓ 7000/10000 procesadas
#   ✓ 7500/10000 procesadas
#   ✓ 8000/10000 procesadas
#   ✓ 8500/10000 procesadas
#   ✓ 9000/10000 procesadas
#   ✓ 9500/10000 procesadas
#   ✓ 10000/10000 procesadas
# ✅ Procesamiento completo

# %%
corpus.distribucion_pos_completa()
# Out:
# ============================================================
# 1. DISTRIBUCIÓN POS COMPLETA (Todos los géneros)
# ============================================================
#
# Categoría POS   Frecuencia   Porcentaje
# ------------------------------------------------------------
# PRON            227,190      20.56       %
# VERB            180,691      16.35       %
# NOUN            160,905      14.56       %
# AUX             89,929       8.14        %
# ADP             87,114       7.88        %
# DET             74,320       6.72        %
# ADV             60,084       5.44        %
# ADJ             50,721       4.59        %
# PROPN           50,352       4.56        %
# PART            36,882       3.34        %
# CCONJ           29,255       2.65        %
# SCONJ           29,111       2.63        %
# INTJ            21,159       1.91        %
# NUM             6,350        0.57        %
# X               999          0.09        %
# PUNCT           72           0.01        %
# SYM             16           0.00        %

# %%
corpus.distribucion_pos_completa('hip hop')
# Out:
# ============================================================
# 1. DISTRIBUCIÓN POS COMPLETA (Género: hip hop)
# ============================================================
#
# Categoría POS   Frecuencia   Porcentaje
# ------------------------------------------------------------
# PRON            108,179      19.72       %
# VERB            88,555       16.14       %
# NOUN            85,769       15.63       %
# ADP             44,674       8.14        %
# AUX             41,349       7.54        %
# DET             38,742       7.06        %
# PROPN           29,479       5.37        %
# ADV             27,172       4.95        %
# ADJ             25,806       4.70        %
# PART            17,458       3.18        %
# CCONJ           13,767       2.51        %
# SCONJ           13,323       2.43        %
# INTJ            10,145       1.85        %
# NUM             3,590        0.65        %
# X               605          0.11        %
# PUNCT           37           0.01        %
# SYM             13           0.00        %

# %%
corpus.distribucion_pos_completa('pop')
# Out:
# ============================================================
# 1. DISTRIBUCIÓN POS COMPLETA (Género: pop)
# ============================================================
#
# Categoría POS   Frecuencia   Porcentaje
# ------------------------------------------------------------
# PRON            119,011      21.39       %
# VERB            92,136       16.56       %
# NOUN            75,136       13.50       %
# AUX             48,580       8.73        %
# ADP             42,440       7.63        %
# DET             35,578       6.39        %
# ADV             32,912       5.91        %
# ADJ             24,915       4.48        %
# PROPN           20,873       3.75        %
# PART            19,424       3.49        %
# SCONJ           15,788       2.84        %
# CCONJ           15,488       2.78        %
# INTJ            11,014       1.98        %
# NUM             2,760        0.50        %
# X               394          0.07        %
# PUNCT           35           0.01        %
# SYM             3            0.00        %
