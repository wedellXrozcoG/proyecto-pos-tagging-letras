# %%
from src.analysis.temporal_analyzer import TemporalAnalyzer

temporal = TemporalAnalyzer("../data/processed/spotify_clean02.csv")
temporal.palabras_mas_usadas_por_decada()
temporal.visualizar_sentimientos()
# Out:
# 🔥 TOP 10 PALABRAS MÁS USADAS POR DÉCADA
#
# 📅 1990s:
#   i               → 7,442
#   the             → 7,319
#   you             → 5,702
#   and             → 4,177
#   a               → 4,121
#   to              → 3,929
#   it              → 3,458
#   my              → 2,438
#   me              → 2,397
#   in              → 2,279
#
# 📅 2000s:
#   i               → 18,276
#   the             → 15,663
#   you             → 13,796
#   and             → 8,737
#   a               → 8,475
#   to              → 7,850
#   it              → 7,434
#   me              → 6,054
#   my              → 5,881
#   in              → 5,386
#
# 📅 2010s:
#   i               → 106,276
#   the             → 69,957
#   you             → 66,053
#   a               → 41,060
#   it              → 36,866
#   and             → 35,541
#   to              → 35,085
#   my              → 33,206
#   me              → 30,934
#   in              → 25,376
#
# 📅 2020s:
#   i               → 68,210
# ...
